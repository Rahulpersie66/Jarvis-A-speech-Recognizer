# %%
#insatll pip pyttsx3 .i.e this module is for spech func and jarvis related code
import pyttsx3
# now imoort date tie module alreday installed
import datetime
# now pip install speechRecognition
import speech_recognition as sr
# conda install -c anaconda pyaudio  u can easily record and play adudio on variety of platform Microsoft , GNU,linux usingPython
import pyaudio
#pip install wikipedia
import wikipedia
#conda install -c intel openmp-mic
#inbuilt webbrowser
import webbrowser
# for playing video, music 
import os
#for sending email and other stuff
import smtplib
hour=int(datetime.datetime.now().hour)
# for taking voices of human there is inbuilt function called sapi5 i.e of microsoft so use that to catch voices
engine=pyttsx3.init('sapi5')
voices=engine.getProperty('voices')# there aretwo voices by default male and female so can choose one of them and can installmany more

#print (voices[1].id)# these are that 2 voices[<pyttsx3.voice.Voice object at 0x0000023F428F6BA8>, <pyttsx3.voice.Voice object at 0x0000023F428F6B70>]
#[0].id is david voice & [1].id is Zira voice
# to ad extra voices use
engine.setProperty('voice',voices[0].id)

#to define a speak function
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
    
# now define wish function all about time
def wishMe():
    hour=(int(datetime.datetime.now().hour))# hour is in 24 range
   
   
    if hour>=6 and hour <11:
        speak('Good Morning Persie Bhai')
    elif hour>=11 & hour <16:
        speak('Good Afternoon Persie bhai')
    elif hour >=16 and hour <20:
        speak('Good evening CAp')
    else:
        speak('Good Night Captain')

    speak('I am JArvis .... Captain How may i help you!')
    
#it take commands from user    
def takeCommand():
   
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Listening.....')
        #r.pause_threshold=1# when i am speaking wait for me to complete sentence i.e wait for 1sec
        #r.energy_threshold increase if there is disturbance ,noise so lud speaking need by default it is 300
        audio=r.listen(source)
   
    try:#when to write try when there may error came
        print('recognizing....')
        query=r.recognize_google(audio)
        print(f"JArvis said :{query}\n")# can also write print("jarvis :",query) the thingprint({query }) is called the fstring
        return query
    except Exception as e:
        #print(e)# some time eror of this came so comment it
        
        print("Say that again Persie Sir....")
        return "None"# it is not of python it is of return string none

#to send mail
def sendEmail(to,Content):
    server=smtplib.SMTP('smtp.gmail.com',587)#poert no. is 587
    server.ehlo()
    server.starttls()
    server.login('Sender@gmail.com','Sender password')#put password in text file for more security# set less secure acces for gmail then only mail can sent 
    server.sendmail('recivermail',to ,content)
    server.close()
    
    
    
#now say
if __name__=="__main__":
    speak("This is ..... JARVIS ")
    wishMe()
    while True:
   # if True:#only for one command 
        query= takeCommand().lower()
        #print(query)
        #logic to execute task
        if 'wikipedia' in query:
            speak('Searching Wiki')
            query=query.replace("wikipedia","")
            results=wikipedia.summary(query,sentences=3)
            speak("According to Persie wikipedia")
            print(results)
            speak(results)
        
        elif 'open youtube' in query:
            webbrowser.open('youtube.com')
            
        elif 'open google' in query:
            webbrowser.open('google.com')
            
        elif 'play music'  in query:
            music_dir='X:\\Mp3\\AMRINDER GILL'#forming a music directory // means escape kr saku char. se
            songs=os.listdir(music_dir)#it will list alll songs in the list 
            #print(songs)# all songs will be printed and all type of songs thatisincluding inmp3
            os.startfile(os.path.join(music_dir,songs[3]))
            
        elif 'the time' in query:
            strtTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"Captain time is {strtTime}")
            
        elif 'coding time' in query:
            codePath="C:\\Program Files\\CodeBlocks\\codeblocks.exe"
            os.startfile(codePath)
            
        elif 'picture time' in query:
            codePath="C:\\Program Files (x86)\\VideoLAN\\VLC\\vlc.exe"
            os.startfile(codePath)
        elif 'email to percy' in query:
            try:
                speak('What shoul ironman  say?')
                content=takeCommand()
                to ="recvier@gmail.com"
                sendEmail(to,content)
                speak('Avenger Email has been sent')
            except Exception as e:
                print(e)
                speak("Soory Avenger Unitation FAilEd")
# Out:
# Listening.....
# recognizing....
# JArvis said :the time
#
# Listening.....
# recognizing....
# JArvis said :open YouTube
#
# Listening.....
# recognizing....
# Say that again Persie Sir....
# Listening.....
# recognizing....
# JArvis said :open Wikipedia black magic
#
# "Black Magic" is a song by British girl group Little Mix. It was written by Camille Purcell, Ed Drewett, Edvard Førre Erfjord, and Henrik Michelsen. The Norwegian production duo Electric, who previously worked on the group's second studio album Salute (2013), produced the single, with additional production from Matt Rad.
# Listening.....
# recognizing....
# JArvis said :open YouTube
#
# Listening.....
# recognizing....
# Say that again Persie Sir....
# Listening.....
# recognizing....
# Say that again Persie Sir....
# Listening.....
# recognizing....
# Say that again Persie Sir....
# Listening.....
# recognizing....
# Say that again Persie Sir....
# Listening.....
# recognizing....
# Say that again Persie Sir....
# ...

# %%
import smtplib

# %%
stri="eestTTTt"
print(stri.lower())
